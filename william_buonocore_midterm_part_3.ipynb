# %% [markdown]
# <a href="https://colab.research.google.com/github/billybuonocore/Finance/blob/main/william_buonocore_midterm_part_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np                   # these breakdown when typing in bars
import matplotlib.pyplot as plt

# %%
x = np.array([12,9,20,7,2])
y = np.array([38,28,63,22,6]) # these are numbers that go onto the chart below

# %%
plt.plot(x,y,'g.') # this is a chart

# %%
m_guess = 0
b_guess = 0

# %%
m_guess * x + b_guess # guesses on array
# Out:
# array([0, 0, 0, 0, 0])

# %% [markdown]
# $y=mx + b$

# %%
y_guess = m_guess * x + b_guess

# %%
y_guess - y # guess minus the y value
# Out:
# array([-38, -28, -63, -22,  -6])

# %%
np.sum((y_guess - y)**2) # sum for numpy
# Out:
# 6717

# %%
loss = np.sum((y_guess - y)**2)

# %%
for m_guess in np.linspace(-100,100,100):        # guess as in numpys linspace with numbers 0-100
  for b_guess in np.linspace(-100,100,100):
    print(m_guess,b_guess)
    y_guess = m_guess * x + b_guess
# Out:
# Streaming output truncated to the last 5000 lines.
# 1.0101010101010104 -100.0
# 1.0101010101010104 -97.97979797979798
# 1.0101010101010104 -95.95959595959596
# 1.0101010101010104 -93.93939393939394
# 1.0101010101010104 -91.91919191919192
# 1.0101010101010104 -89.8989898989899
# 1.0101010101010104 -87.87878787878788
# 1.0101010101010104 -85.85858585858585
# 1.0101010101010104 -83.83838383838383
# 1.0101010101010104 -81.81818181818181
# 1.0101010101010104 -79.79797979797979
# 1.0101010101010104 -77.77777777777777
# 1.0101010101010104 -75.75757575757575
# 1.0101010101010104 -73.73737373737373
# 1.0101010101010104 -71.71717171717171
# 1.0101010101010104 -69.69696969696969
# 1.0101010101010104 -67.67676767676767
# 1.0101010101010104 -65.65656565656565
# 1.0101010101010104 -63.63636363636363
# 1.0101010101010104 -61.61616161616161
# 1.0101010101010104 -59.59595959595959
# 1.0101010101010104 -57.57575757575757
# 1.0101010101010104 -55.55555555555555
# 1.0101010101010104 -53.53535353535353
# ...

# %%
best_loss_so_far = 10000000000
m_best = 0
b_best = 0

for m_guess in np.linspace(-100,100,100):
  for b_guess in np.linspace(-100,100,100):
  
    y_guess = m_guess * x + b_guess

    loss = np.sum((y_guess - y)**2)

    print(m_guess,b_guess,loss)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1.0101010101010104 -100.0 74396.6449341904
# 1.0101010101010104 -97.97979797979798 71966.56637077848
# 1.0101010101010104 -95.95959595959596 69577.29996939088
# 1.0101010101010104 -93.93939393939394 67228.84573002755
# 1.0101010101010104 -91.91919191919192 64921.20365268849
# 1.0101010101010104 -89.8989898989899 62654.373737373724
# 1.0101010101010104 -87.87878787878788 60428.35598408325
# 1.0101010101010104 -85.85858585858585 58243.15039281704
# 1.0101010101010104 -83.83838383838383 56098.75696357514
# 1.0101010101010104 -81.81818181818181 53995.17569635751
# 1.0101010101010104 -79.79797979797979 51932.40659116416
# 1.0101010101010104 -77.77777777777777 49910.4496479951
# 1.0101010101010104 -75.75757575757575 47929.30486685031
# 1.0101010101010104 -73.73737373737373 45988.97224772981
# 1.0101010101010104 -71.71717171717171 44089.4517906336
# 1.0101010101010104 -69.69696969696969 42230.74349556167
# ...

# %%
best_loss_so_far = 10000000000 # also another guess with m and y guesses from 0-3
m_best = 0
b_best = 0

for m_guess in np.linspace(-100,100,100):
  for b_guess in np.linspace(-100,100,100):
  
    y_guess = m_guess * x + b_guess

    loss = np.sum((y_guess - y)**2)

    print(m_guess,b_guess,loss)

    if loss < best_loss_so_far:
      m_best = m_guess
      b_best = b_guess
      best_loss_so_far = loss 
      print("Found better fit:")
      print(m_guess,b_guess,loss)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1.0101010101010104 -27.272727272727266 12625.47872666054
# 1.0101010101010104 -25.252525252525245 11664.63799612284
# 1.0101010101010104 -23.232323232323225 10744.609427609423
# 1.0101010101010104 -21.212121212121204 9865.393021120288
# 1.0101010101010104 -19.191919191919183 9026.988776655438
# 1.0101010101010104 -17.171717171717162 8229.39669421487
# 1.0101010101010104 -15.151515151515142 7472.616773798587
# 1.0101010101010104 -13.13131313131312 6756.649015406586
# 1.0101010101010104 -11.1111111111111 6081.4934190388685
# 1.0101010101010104 -9.09090909090908 5447.149984695434
# 1.0101010101010104 -7.0707070707070585 4853.618712376283
# 1.0101010101010104 -5.050505050505038 4300.899602081416
# 1.0101010101010104 -3.030303030303031 3788.992653810835
# 1.0101010101010104 -1.0101010101010104 3317.8978675645335
# 1.0101010101010104 1.0101010101010104 2887.615243342515
# Found better fit:
# ...

# %%
best_loss_so_far = 10000000000
m_best = 0
b_best = 0

for m_guess in np.linspace(-100,100,100):
  for b_guess in np.linspace(-100,100,100):
  
    y_guess = m_guess * x + b_guess

    loss = np.sum((y_guess - y)**2)

    print(m_guess,b_guess,loss)

    if loss < best_loss_so_far:
      m_best = m_guess
      b_best = b_guess
      best_loss_so_far = loss 
     
    print("Found best fit:")
    print(m_best,b_best,loss)
# Out:
# Streaming output truncated to the last 5000 lines.
# Found best fit:
# 3.030303030303031 1.0101010101010104 2613643.7829813296
# 67.6767676767677 -31.313131313131308 2626028.5192327327
# Found best fit:
# 3.030303030303031 1.0101010101010104 2626028.5192327327
# 67.6767676767677 -29.292929292929287 2638454.06764616
# Found best fit:
# 3.030303030303031 1.0101010101010104 2638454.06764616
# 67.6767676767677 -27.272727272727266 2650920.428221612
# Found best fit:
# 3.030303030303031 1.0101010101010104 2650920.428221612
# 67.6767676767677 -25.252525252525245 2663427.6009590873
# Found best fit:
# 3.030303030303031 1.0101010101010104 2663427.6009590873
# 67.6767676767677 -23.232323232323225 2675975.585858587
# Found best fit:
# 3.030303030303031 1.0101010101010104 2675975.585858587
# 67.6767676767677 -21.212121212121204 2688564.3829201115
# Found best fit:
# 3.030303030303031 1.0101010101010104 2688564.3829201115
# 67.6767676767677 -19.191919191919183 2701193.992143661
# Found best fit:
# ...

# %%
best_loss_so_far = 1000000000000            # best guesses from 0-3
m_best = 0 
b_best = 0 
for m_guess in np.linspace(-100,100,100):
    for b_guess in np.linspace(-100,100,100):
        
        y_guess = m_guess * x + b_guess

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss_so_far:
            m_best = m_guess
            b_best = b_guess
            best_loss_so_far = loss

print("Found best fit:")
print(m_best,b_best,loss)
# Out:
# Found best fit:
# 3.030303030303031 1.0101010101010104 7378517.0
